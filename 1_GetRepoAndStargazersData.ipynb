# %%
import networkx as nx
import pandas as pd
import requests
import matplotlib.pyplot as plt
import json
from datetime import datetime

# %% [markdown]
# #Get the data

# %% [markdown]
# Process of retrieving data from GitHub using the GitHub API. The main goal is to collect information about repositories written in the Rust programming language that were created after April 1st, as well as the users who have shown interest in them by starring them.

# %% [markdown]
# ##Get recent repos

# %%
def get_recent_repositories():
    """
    Fetches recent repositories created after April 1, 2024, sorted by stars.

    Returns:
        list: List of dictionaries containing information about the repositories.
    """
    url = 'https://api.github.com/search/repositories'

    params = {
        'q': 'created:>=2024-04-01 language:rust',
        'sort': 'stars',
        'order': 'desc',
        'per_page': 50
    }

    response = requests.get(url, params=params)

    if response.status_code == 200:
        data = response.json()
        repositories = data.get('items', [])
        return repositories
    else:
        print("Failed to fetch repositories")
        return None

# %%
repositories = get_recent_repositories()

# %%
df = pd.DataFrame(repositories)

# %%
df.head()
# Out:
#           id       node_id                    name  \
# 0  786035979  R_kgDOLtn1Cw               ore-miner
# 1  782547300  R_kgDOLqS5ZA                 ClangQL
# 2  793955649  R_kgDOL1LNQQ        offset-allocator
# 3  780688305  R_kgDOLohbsQ  good_training_language
# 4  780764359  R_kgDOLomExw             nix-inspect
#
#                         full_name  private  \
# 0            tonyke-bot/ore-miner    False
# 1            AmrDeveloper/ClangQL    False
# 2       pcwalton/offset-allocator    False
# 3  tsoding/good_training_language    False
# 4           bluskript/nix-inspect    False
#
#                                                owner  \
# 0  {'login': 'tonyke-bot', 'id': 14999583, 'node_...
# 1  {'login': 'AmrDeveloper', 'id': 23631699, 'nod...
# 2  {'login': 'pcwalton', 'id': 157897, 'node_id':...
# 3  {'login': 'tsoding', 'id': 18597647, 'node_id'...
# 4  {'login': 'bluskript', 'id': 52386117, 'node_i...
#
#                                             html_url  \
# 0            https://github.com/tonyke-bot/ore-miner
# 1            https://github.com/AmrDeveloper/ClangQL
# 2       https://github.com/pcwalton/offset-allocator
# 3  https://github.com/tsoding/good_training_language
# 4           https://github.com/bluskript/nix-inspect
#
#                                          description   fork  \
# 0  ORE Miner built on top of Jito bundle with bot...  False
# 1   ClangQL is a tool that allow you to run SQL-l...  False
# 2  A port of Sebastian Aaltonen's `OffsetAllocato...  False
# 3                               Хороший Учебный Язык  False
# 4         Interactive tui for inspecting nix configs  False
#
#                                                  url  ... allow_forking  \
# 0  https://api.github.com/repos/tonyke-bot/ore-miner  ...          True
# 1  https://api.github.com/repos/AmrDeveloper/ClangQL  ...          True
# 2  https://api.github.com/repos/pcwalton/offset-a...  ...          True
# 3  https://api.github.com/repos/tsoding/good_trai...  ...          True
# 4  https://api.github.com/repos/bluskript/nix-ins...  ...          True
#
#   is_template web_commit_signoff_required  \
# 0       False                       False
# 1       False                       False
# 2       False                       False
# 3       False                       False
# 4       False                       False
#
#                                               topics visibility forks  \
# 0                                                 []     public   212
# 1  [ast, clang, cpp, database, gitql, llvm, llvm-...     public     8
# 2                                                 []     public     5
# 3                                                 []     public     5
# 4                                                 []     public     2
#
#   open_issues watchers default_branch score
# 0          19      461           main   1.0
# 1           7      428         master   1.0
# 2           1      351           main   1.0
# 3           2      317           main   1.0
# 4           5      244           main   1.0
#
# [5 rows x 80 columns]

# %%
print("\nUnique Languages:")
print(df['language'].unique())
# Out:
# Unique Languages:
# ['Rust']

# %%
from tabulate import tabulate

stats = {
    'Minimum number of stars': [df['stargazers_count'].min()],
    'Q1 (25th percentile)': [df['stargazers_count'].quantile(0.25)],
    'Median (Q2)': [df['stargazers_count'].quantile(0.5)],
    'Q3 (75th percentile)': [df['stargazers_count'].quantile(0.75)],
    'Maximum number of stars': [df['stargazers_count'].max()]
}

stats_df = pd.DataFrame(stats)
print(tabulate(stats_df, headers='keys', tablefmt='pretty', showindex=False))
# Out:
# +-------------------------+----------------------+-------------+----------------------+-------------------------+
# | Minimum number of stars | Q1 (25th percentile) | Median (Q2) | Q3 (75th percentile) | Maximum number of stars |
# +-------------------------+----------------------+-------------+----------------------+-------------------------+
# |          26.0           |         31.0         |    42.5     |        111.5         |          461.0          |
# +-------------------------+----------------------+-------------+----------------------+-------------------------+

# %%
import csv
import json

def save_to_csv_full(repositories, filename):
    """
    Saves full repository data to a CSV file.

    Args:
        repositories (list): List of dictionaries containing repository information.
        filename (str): Name of the CSV file to save.
    """
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = set().union(*(repo.keys() for repo in repositories))

        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)

        writer.writeheader()

        for repo in repositories:
            writer.writerow(repo)

def save_to_json_full(repositories, filename):
    """
    Saves full repository data to a JSON file.

    Args:
        repositories (list): List of dictionaries containing repository information.
        filename (str): Name of the JSON file to save.
    """
    with open(filename, 'w', encoding='utf-8') as jsonfile:
        json.dump(repositories, jsonfile, indent=4)

# %%
save_to_csv_full(repositories, 'recent_repositories_from_april.csv')
save_to_json_full(repositories, 'recent_repositories_from_april.json')

# %%
import shutil

def move_files_to_data_folder():
    csv_file_path = 'recent_repositories_from_april.csv'
    json_file_path = 'recent_repositories_from_april.json'
    data_folder_path = '/content/drive/MyDrive/PMF 2 4/STROJNO + MREŽE/Data'

    try:
        shutil.move(csv_file_path, data_folder_path)
        print("CSV file moved successfully to 'data' folder.")
        shutil.move(json_file_path, data_folder_path)
        print("JSON file moved successfully to 'data' folder.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
move_files_to_data_folder()
# Out:
# CSV file moved successfully to 'data' folder.
# JSON file moved successfully to 'data' folder.

# %% [markdown]
# ##Get stargazers for recent repos

# %%
import pandas as pd
import requests
import json

# %%
df = pd.read_csv('/content/drive/MyDrive/PMF 2 4/STROJNO + MREŽE/Data/recent_repositories_from_april.csv')

df.head()
# Out:
#                                           merges_url  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1  https://api.github.com/repos/AmrDeveloper/Clan...
# 2  https://api.github.com/repos/pcwalton/offset-a...
# 3  https://api.github.com/repos/tsoding/good_trai...
# 4  https://api.github.com/repos/bluskript/nix-ins...
#
#                                    issue_comment_url  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1  https://api.github.com/repos/AmrDeveloper/Clan...
# 2  https://api.github.com/repos/pcwalton/offset-a...
# 3  https://api.github.com/repos/tsoding/good_trai...
# 4  https://api.github.com/repos/bluskript/nix-ins...
#
#                                            teams_url  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1  https://api.github.com/repos/AmrDeveloper/Clan...
# 2  https://api.github.com/repos/pcwalton/offset-a...
# 3  https://api.github.com/repos/tsoding/good_trai...
# 4  https://api.github.com/repos/bluskript/nix-ins...
#
#                                         branches_url  size       node_id  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...    65  R_kgDOLtn1Cw
# 1  https://api.github.com/repos/AmrDeveloper/Clan...  1657  R_kgDOLqS5ZA
# 2  https://api.github.com/repos/pcwalton/offset-a...    26  R_kgDOL1LNQQ
# 3  https://api.github.com/repos/tsoding/good_trai...  2299  R_kgDOLohbsQ
# 4  https://api.github.com/repos/bluskript/nix-ins...   207  R_kgDOLomExw
#
#     fork  forks                                        commits_url  \
# 0  False    212  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1  False      8  https://api.github.com/repos/AmrDeveloper/Clan...
# 2  False      5  https://api.github.com/repos/pcwalton/offset-a...
# 3  False      5  https://api.github.com/repos/tsoding/good_trai...
# 4  False      2  https://api.github.com/repos/bluskript/nix-ins...
#
#                                        languages_url  ...  disabled  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...  ...     False
# 1  https://api.github.com/repos/AmrDeveloper/Clan...  ...     False
# 2  https://api.github.com/repos/pcwalton/offset-a...  ...     False
# 3  https://api.github.com/repos/tsoding/good_trai...  ...     False
# 4  https://api.github.com/repos/bluskript/nix-ins...  ...     False
#
#                         full_name  \
# 0            tonyke-bot/ore-miner
# 1            AmrDeveloper/ClangQL
# 2       pcwalton/offset-allocator
# 3  tsoding/good_training_language
# 4           bluskript/nix-inspect
#
#                                       milestones_url  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1  https://api.github.com/repos/AmrDeveloper/Clan...
# 2  https://api.github.com/repos/pcwalton/offset-a...
# 3  https://api.github.com/repos/tsoding/good_trai...
# 4  https://api.github.com/repos/bluskript/nix-ins...
#
#                                     issue_events_url  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1  https://api.github.com/repos/AmrDeveloper/Clan...
# 2  https://api.github.com/repos/pcwalton/offset-a...
# 3  https://api.github.com/repos/tsoding/good_trai...
# 4  https://api.github.com/repos/bluskript/nix-ins...
#
#                                         contents_url             pushed_at  \
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...  2024-04-16T02:16:07Z
# 1  https://api.github.com/repos/AmrDeveloper/Clan...  2024-05-09T01:47:39Z
# 2  https://api.github.com/repos/pcwalton/offset-a...  2024-05-02T17:54:01Z
# 3  https://api.github.com/repos/tsoding/good_trai...  2024-04-07T13:18:19Z
# 4  https://api.github.com/repos/bluskript/nix-ins...  2024-04-19T02:21:13Z
#
#   language                                         issues_url  \
# 0     Rust  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1     Rust  https://api.github.com/repos/AmrDeveloper/Clan...
# 2     Rust  https://api.github.com/repos/pcwalton/offset-a...
# 3     Rust  https://api.github.com/repos/tsoding/good_trai...
# 4     Rust  https://api.github.com/repos/bluskript/nix-ins...
#
#                                              license  \
# 0                                                NaN
# 1  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 2  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
# 3                                                NaN
# 4  {'key': 'mit', 'name': 'MIT License', 'spdx_id...
#
#                                          archive_url
# 0  https://api.github.com/repos/tonyke-bot/ore-mi...
# 1  https://api.github.com/repos/AmrDeveloper/Clan...
# 2  https://api.github.com/repos/pcwalton/offset-a...
# 3  https://api.github.com/repos/tsoding/good_trai...
# 4  https://api.github.com/repos/bluskript/nix-ins...
#
# [5 rows x 80 columns]

# %%
with open('/content/drive/MyDrive/PMF 2 4/STROJNO + MREŽE/Data/recent_repositories_from_april.json', 'r') as file:
    repository_data = json.load(file)

# %%
def stargazers_for_recent_repos(repo_owner, repo_name, api_token):
    """
    Fetches all stargazers of a GitHub repository, handling pagination.

    Args:
        repo_owner (str): The username of the repository owner.
        repo_name (str): The name of the repository.
        api_token (str): GitHub API token.

    Returns:
        list: List of dictionaries containing information about the stargazers.
    """
    url = f'https://api.github.com/repos/{repo_owner}/{repo_name}/stargazers'
    headers = {"Authorization": f"token {api_token}"}

    stargazers = []
    total_stargazers = 0
    next_page = 1

    while next_page:
        response = requests.get(url, headers=headers, params={"page": next_page})

        if response.status_code == 200:
            data = response.json()

            stargazers.extend([{'repository_name': repo_name, 'username': user.get('login', ''), 'user_id': user.get('id', '')} for user in data])

            total_stargazers += len(data)

            if 'next' in response.links:
                next_page += 1
            else:
                next_page = None
        else:
            print(f"Failed to fetch stargazers for {repo_name}. Status Code: {response.status_code}")
            return None

    print(f"Number of fetched stargazers for {repo_name}: {total_stargazers}")

    return stargazers

# %%
all_stargazers_df_recent_repos = pd.DataFrame(columns=['repository_name', 'username', 'user_id'])

# %%
# Iterate through the repositories in the JSON data and fetch stargazers
for repo in repository_data:
    owner = repo['owner']['login']
    name = repo['name']

    api_token = "YOUR_TOKEN"

    stargazers = stargazers_for_recent_repos(owner, name, api_token)

    if stargazers:
        print(f"Stargazers data for {name} fetched successfully.")
        all_stargazers_df_recent_repos = pd.concat([all_stargazers_df_recent_repos, pd.DataFrame(stargazers)], ignore_index=True)
    else:
        print(f"Failed to fetch stargazers data for {name}.")
# Out:
# Number of fetched stargazers for ore-miner: 461
# Stargazers data for ore-miner fetched successfully.
# Number of fetched stargazers for ClangQL: 428
# Stargazers data for ClangQL fetched successfully.
# Number of fetched stargazers for offset-allocator: 351
# Stargazers data for offset-allocator fetched successfully.
# Number of fetched stargazers for good_training_language: 316
# Stargazers data for good_training_language fetched successfully.
# Number of fetched stargazers for nix-inspect: 243
# Stargazers data for nix-inspect fetched successfully.
# Number of fetched stargazers for ore-cli-gpu: 230
# Stargazers data for ore-cli-gpu fetched successfully.
# Number of fetched stargazers for jailbreak-11: 176
# Stargazers data for jailbreak-11 fetched successfully.
# Number of fetched stargazers for haystackdb: 153
# Stargazers data for haystackdb fetched successfully.
# Number of fetched stargazers for three_body: 150
# Stargazers data for three_body fetched successfully.
# Number of fetched stargazers for binary_greedy_mesher_demo: 149
# Stargazers data for binary_greedy_mesher_demo fetched successfully.
# Number of fetched stargazers for ninjabook: 122
# Stargazers data for ninjabook fetched successfully.
# Number of fetched stargazers for get-selected-text: 118
# Stargazers data for get-selected-text fetched successfully.
# Number of fetched stargazers for jf: 112
# Stargazers data for jf fetched successfully.
# Number of fetched stargazers for rust-practice: 110
# Stargazers data for rust-practice fetched successfully.
# Number of fetched stargazers for fgpt: 83
# Stargazers data for fgpt fetched successfully.
# Number of fetched stargazers for symbolizer-rs: 59
# Stargazers data for symbolizer-rs fetched successfully.
# Number of fetched stargazers for ruxt.rs: 52
# Stargazers data for ruxt.rs fetched successfully.
# Number of fetched stargazers for utility: 51
# Stargazers data for utility fetched successfully.
# Number of fetched stargazers for integrationos: 50
# Stargazers data for integrationos fetched successfully.
# Number of fetched stargazers for ctreg: 48
# Stargazers data for ctreg fetched successfully.
# Number of fetched stargazers for tiron: 48
# Stargazers data for tiron fetched successfully.
# Number of fetched stargazers for CVE-2024-24576-PoC: 46
# Stargazers data for CVE-2024-24576-PoC fetched successfully.
# Number of fetched stargazers for ascii_art: 45
# Stargazers data for ascii_art fetched successfully.
# Number of fetched stargazers for ratatui_egui_wasm: 44
# Stargazers data for ratatui_egui_wasm fetched successfully.
# Number of fetched stargazers for zkvm-benchmarks: 43
# Stargazers data for zkvm-benchmarks fetched successfully.
# Number of fetched stargazers for diol: 42
# Stargazers data for diol fetched successfully.
# Number of fetched stargazers for biome-zed: 41
# Stargazers data for biome-zed fetched successfully.
# Number of fetched stargazers for cord.nvim: 40
# Stargazers data for cord.nvim fetched successfully.
# Number of fetched stargazers for tx-coverage: 40
# Stargazers data for tx-coverage fetched successfully.
# Number of fetched stargazers for memento-master: 38
# Stargazers data for memento-master fetched successfully.
# Number of fetched stargazers for music-generation: 37
# Stargazers data for music-generation fetched successfully.
# Number of fetched stargazers for Snippy: 37
# Stargazers data for Snippy fetched successfully.
# Number of fetched stargazers for tvisor: 34
# Stargazers data for tvisor fetched successfully.
# Number of fetched stargazers for sentrum: 34
# Stargazers data for sentrum fetched successfully.
# Number of fetched stargazers for CUDA-ORE-DUMP: 34
# Stargazers data for CUDA-ORE-DUMP fetched successfully.
# Number of fetched stargazers for modular-svm: 32
# Stargazers data for modular-svm fetched successfully.
# Number of fetched stargazers for fast-graph: 31
# Stargazers data for fast-graph fetched successfully.
# Number of fetched stargazers for interceptor: 31
# Stargazers data for interceptor fetched successfully.
# Number of fetched stargazers for block-stm-revm: 31
# Stargazers data for block-stm-revm fetched successfully.
# Number of fetched stargazers for rust-tracing-primer: 30
# Stargazers data for rust-tracing-primer fetched successfully.
# Number of fetched stargazers for ffd: 30
# Stargazers data for ffd fetched successfully.
# Number of fetched stargazers for error_set: 30
# Stargazers data for error_set fetched successfully.
# Number of fetched stargazers for inkmate: 30
# Stargazers data for inkmate fetched successfully.
# Number of fetched stargazers for Liquidator-Morpho: 28
# Stargazers data for Liquidator-Morpho fetched successfully.
# Number of fetched stargazers for How-not-to-async-rs: 28
# Stargazers data for How-not-to-async-rs fetched successfully.
# Number of fetched stargazers for rudis: 27
# Stargazers data for rudis fetched successfully.
# Number of fetched stargazers for forge-flamegraph: 26
# Stargazers data for forge-flamegraph fetched successfully.
# Number of fetched stargazers for curvo: 26
# Stargazers data for curvo fetched successfully.
# Number of fetched stargazers for Incredible.dev: 26
# Stargazers data for Incredible.dev fetched successfully.
# Number of fetched stargazers for rust-dyn-proxy: 26
# Stargazers data for rust-dyn-proxy fetched successfully.

# %%
all_stargazers_df_recent_repos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4497 entries, 0 to 4496
# Data columns (total 3 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   repository_name  4497 non-null   object
#  1   username         4497 non-null   object
#  2   user_id          4497 non-null   object
# dtypes: object(3)
# memory usage: 105.5+ KB

# %%
all_stargazers_df_recent_repos.to_csv('all_stargazers_for_recent_repos.csv', index=False)
print("Stargazers data saved to CSV file.")

all_stargazers_df_recent_repos.to_json('all_stargazers_for_recent_repos.json', orient='records', lines=True)
print("Stargazers data saved to JSON file.")
# Out:
# Stargazers data saved to CSV file.
# Stargazers data saved to JSON file.

# %%
folder_path = '/content/drive/MyDrive/PMF 2 4/STROJNO + MREŽE/Data'

all_stargazers_df_recent_repos.to_csv(folder_path + 'all_stargazers_for_recent_repos.csv', index=False)
all_stargazers_df_recent_repos.to_json(folder_path + 'all_stargazers_for_recent_repos.json', orient='records', lines=True)

print("Files saved to Google Drive.")
# Out:
# Files saved to Google Drive.
